# %%
from data_API_downloader import DataPipeline
from visualizer import VisualizerOfCriminalData
pipeline = DataPipeline(crime_data = None, create_data = False)
pipeline.match_crime_data_to_polygons()
pipeline.compute_counts_per_polygon()
pipeline.preprocess_paq_data()
table = pipeline.merge_final_table()

# %%
#Now we initialize the visualizer with the data created from pipeline
visualizer = VisualizerOfCriminalData(table)
maps = visualizer.get_folium_maps()
labels = visualizer.english_legend_name_buffer

# %%
#show to map for the first variable and its label (the index goes from 0 to 5)
print(labels[0])
maps[0]
# Out:
# Criminality per capita
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ddf2ae27f7becb0fb1d028e0ed17a50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ddf2ae27f7becb0fb1d028e0ed17a50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ddf2ae27f7becb0fb1d028e0ed17a50 = L.map(
#                 &quot;map_0ddf2ae27f7becb0fb1d028e0ed17a50&quot;,
#                 {
#                     center: [49.8037633, 15.4749126],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8.4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64c9efb9efbc75c29c52b6eb131dd2d0 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0ddf2ae27f7becb0fb1d028e0ed17a50);
#
#
#             var choropleth_2066c2cb659828582db3378ccfbc86aa = L.featureGroup(
#                 {}
#             ).addTo(map_0ddf2ae27f7becb0fb1d028e0ed17a50);
#
#
#         function geo_json_bdc82f43414def672aba7acbea5db26e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;6&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;20&quot;: case &quot;32&quot;: case &quot;33&quot;: case &quot;39&quot;: case &quot;45&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;55&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;72&quot;: case &quot;76&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;83&quot;: case &quot;84&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;97&quot;: case &quot;101&quot;: case &quot;102&quot;: case &quot;103&quot;: case &quot;105&quot;: case &quot;111&quot;: case &quot;114&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;132&quot;: case &quot;133&quot;: case &quot;135&quot;: case &quot;137&quot;: case &quot;140&quot;: case &quot;146&quot;: case &quot;155&quot;: case &quot;165&quot;: case &quot;170&quot;: case &quot;171&quot;: case &quot;173&quot;: case &quot;174&quot;: case &quot;176&quot;: case &quot;177&quot;: case &quot;183&quot;: case &quot;184&quot;: case &quot;194&quot;: case &quot;201&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9ef8b&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;12&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;54&quot;: case &quot;56&quot;: case &quot;65&quot;: case &quot;71&quot;: case &quot;74&quot;: case &quot;99&quot;: case &quot;100&quot;: case &quot;120&quot;: case &quot;121&quot;: case &quot;124&quot;: case &quot;178&quot;: case &quot;180&quot;: case &quot;181&quot;: case &quot;185&quot;: case &quot;188&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fee08b&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;13&quot;: case &quot;50&quot;: case &quot;130&quot;: case &quot;195&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d73027&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;23&quot;: case &quot;40&quot;: case &quot;42&quot;: case &quot;47&quot;: case &quot;49&quot;: case &quot;70&quot;: case &quot;125&quot;: case &quot;141&quot;: case &quot;143&quot;: case &quot;144&quot;: case &quot;160&quot;: case &quot;167&quot;: case &quot;192&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#1a9850&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;107&quot;: case &quot;122&quot;: case &quot;123&quot;: case &quot;179&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fc8d59&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#91cf60&quot;, &quot;fillOpacity&quot;: 0.8, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_bdc82f43414def672aba7acbea5db26e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         v

# %%
visualizer.show_scatter_correlations()

# %%
visualizer.show_correlation_heatmap()
