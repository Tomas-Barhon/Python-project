# %%
#importing modules
from data_API_downloader import Downloader

# %%
#How to use Downloader for single month only

#initialize with the year you want to download the data for
download = Downloader(year= 2012,month = 5)
#send the get request to obtain the zip file
download.get_request()
#unzip the downloaded file and get .csv file for the month
download.unzip_files_return_dataframe()
# Out:
# 200
#       id          x          y     mp                            date  state  \
# 0   3114  16.634512  49.401482  False  2012-05-08T03:32:00.0000+02:00      1
# 1   3114  16.634512  49.401482  False  2012-05-08T03:32:00.0000+02:00      1
# 2   3114  16.634512  49.401482  False  2012-05-08T03:32:00.0000+02:00      1
# 3   3116  16.565665  49.396088  False  2012-05-07T22:17:00.0000+02:00      1
# 4   3116  16.565665  49.396088  False  2012-05-07T22:17:00.0000+02:00      1
# ..   ...        ...        ...    ...                             ...    ...
# 85  9723  15.144309  50.599507  False  2012-05-31T04:34:00.0000+02:00      1
# 86  9723  15.144309  50.599507  False  2012-05-31T04:34:00.0000+02:00      1
# 87  9905  15.167933  50.731134  False  2012-05-04T18:49:00.0000+02:00      1
# 88  9905  15.167933  50.731134  False  2012-05-04T18:49:00.0000+02:00      1
# 89  9905  15.167933  50.731134  False  2012-05-04T18:49:00.0000+02:00      1
#
#     relevance  types
# 0           1     74
# 1           1     97
# 2           1    120
# 3           1     74
# 4           1     97
# ..        ...    ...
# 85          1     97
# 86          1    120
# 87          4      1
# 88          4      3
# 89          4      5
#
# [90 rows x 8 columns]

# %%
#How to use Downloader to download data for multiple years
crime_data = download.get_multiple_years(years = [2012,2013,2014])
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
#                id          x          y     mp  \
# 0             739  17.316089  49.302210  False
# 1             739  17.316089  49.302210  False
# 2             739  17.316089  49.302210  False
# 3             739  17.316089  49.302210  False
# 4            1075  14.585108  50.226063  False
# ...           ...        ...        ...    ...
# 4300488   4069788  15.052843  50.776110  False
# 4300489  15176385  17.116643  49.470339  False
# 4300490  19920173  18.549768  49.846361  False
# 4300491  19920173  18.549768  49.846361  False
# 4300492  19920173  18.549768  49.846361  False
#
#                                    date  state  relevance  types
# 0        2012-01-19T13:14:00.0000+01:00      1          1     35
# 1        2012-01-19T13:14:00.0000+01:00      1          1     55
# 2        2012-01-19T13:14:00.0000+01:00      1          1    101
# 3        2012-01-19T13:14:00.0000+01:00      1          1    102
# 4        2012-01-26T16:00:00.0000+01:00      1          4     74
# ...                                 ...    ...        ...    ...
# 4300488  2014-12-30T16:50:00.0000+01:00      1          2    119
# 4300489  2014-12-16T11:16:00.0000+01:00      1          3     54
# 4300490  2014-12-01T23:45:00.0000+01:00      1          4     74
# 4300491  2014-12-01T23:45:00.0000+01:00      1          4     97
# 4300492  2014-12-01T23:45:00.0000+01:00      1          4    120
#
# [4300493 rows x 8 columns]
